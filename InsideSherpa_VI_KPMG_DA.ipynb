# %% [markdown]
# # KMPG Virtual Intership: Inside Sherpa

# %% [markdown]
# In this notebook, I hope to show how a data analyst might work through a problem using the R programming language.

# %% [markdown]
# ## Overview
#
# 1. Problem
# 2. Data
# 3. Data Visualization
# 5. Conclusion

# %% [markdown]
# ### 1. Problem
#
# Sprocket Pty Ltd needs help with marketing and customer acquisition.
# Primarily, Sprocket Central Pty Ltd needs help with its customer and transactions data. The organisation has a large dataset relating to its customers, but their team is unsure how to effectively analyse it to help optimise its marketing strategy.

# %%
#install packages
install.packages("ggplot2")
install.packages("dplyr")
# Out:
# package 'ggplot2' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\vbthe\AppData\Local\Temp\RtmpWcbxHX\downloaded_packages
# Installing package into 'C:/Users/vbthe/OneDrive/Documents/R/win-library/4.0'
# (as 'lib' is unspecified)
# package 'dplyr' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\vbthe\AppData\Local\Temp\RtmpWcbxHX\downloaded_packages

# %%
#call on packages using library
library(ggplot2)
library(dplyr)
# Out:
# Warning message:
# "package 'ggplot2' was built under R version 4.0.2"
# Warning message:
# "package 'dplyr' was built under R version 4.0.2"
#
# Attaching package: 'dplyr'
#
#
# The following objects are masked from 'package:stats':
#
#     filter, lag
#
#
# The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union

# %% [markdown]
# ### 2. Data
#
# Each sheet in the excel file was extracted and formated to a .csv file.
# 1. TRANSACTION_KPMG.csv
# 2. CUSADD_KPMG.csv
# 3. newcus_kpmg.csv

# %%
#uplaoded Trasaction dataset as csv
data <- read.csv("TRANSACTION_KPMG.csv", header = TRUE)

# %%
data
# Out:
#       transaction_id product_id customer_id transaction_date online_order
# 1        94          86         1           12/23/2017       FALSE
# 2      3765          38         1           4/6/2017          TRUE
# 3      5157          47         1           5/11/2017         TRUE
# 4      9785          72         1           1/5/2017         FALSE
# 5     13424           2         1           2/21/2017        FALSE
# 6     13644          25         1           5/19/2017        FALSE
# 7     14486          23         1           3/27/2017        FALSE
# 8     14931          31         1           12/14/2017        TRUE
# 9     15663          32         1           6/4/2017          TRUE
# 10    16423           9         1           12/9/2017         TRUE
# 11    18970          11         1           3/29/2017         TRUE
# 12     2261           1         2           5/4/2017          TRUE
# 13     6743          85         2           6/11/2017        FALSE
# ...

# %% [markdown]
# ### 3. Data Visualization

# %%
#shows that Solex has the most occurances in the dataset
chart1 <- qplot(data$brand, geom = "bar",
               xlab = "Cycle Brand", ylab = "Occurances",
               main = "Number of times the Brands show up") + aes(fill = ..count..)
chart1
# Out:
# plot without title

# %% [markdown]
# Solex occurs most often in the dataset implying that it is most sold brand at Sprocket

# %%
#brand and profit
chart2 <- ggplot(data, aes(x = brand, y = Profit, fill = brand)
                , xlab = "Cycle Brand" , 
                 ylab = "Profit per Brand" ) + geom_bar(stat = "identity") + theme(axis.text.x = element_text(angle =90))
                
                
print(chart2 + ggtitle("Brands that bring in the most profit"))
# Out:
# plot without title

# %% [markdown]
# While, Solex is the most sold brand, WeareA2B brings in the most profit

# %%
#uploaded modified customer address dataset as csv
data1 <- read.csv("CUSADD_KPMG.csv", header = TRUE)
data1
# Out:
#      customer_id address                    postcode state           country
# 1     1          060 Morning Avenue         2016     New South Wales Australia
# 2     2          6 Meadow Vale Court        2153     New South Wales Australia
# 3     4          0 Holy Cross Court         4211     QLD             Australia
# 4     5          17979 Del Mar Point        2448     New South Wales Australia
# 5     6          9 Oakridge Court           3216     Victoria        Australia
# 6     7          4 Delaware Trail           2210     New South Wales Australia
# 7     8          49 Londonderry Lane        2650     New South Wales Australia
# 8     9          97736 7th Trail            2023     New South Wales Australia
# 9    11          93405 Ludington Park       3044     Victoria        Australia
# 10   12          44339 Golden Leaf Alley    4557     QLD             Australia
# 11   13          2 Sutherland Street        3799     Victoria        Australia
# ...

# %%
#Coustomers are mostly from which State in Australia
chart3 <- qplot(data1$state, geom = "bar", xlab = "States in Australia", ylab = "Ocurrances", 
                main = "Number of times each State shows up") + aes(fill = ..count..)
chart3
# Out:
# plot without title

# %% [markdown]
# Most customer are from New South Wales

# %%
#uploaded data for new cusotmer list provided in module 3
data2 <- read.csv("newcus_kpmg.csv", header = TRUE)
data2
# Out:
#     first_name last_name    gender past_3_years_bike_related_purchases
# 1   Chickie    Brister      Male   86
# 2   Morly      Genery       Male   69
# 3   Ardelis    Forrester    Female 10
# 4   Lucine     Stutt        Female 64
# 5   Melinda    Hadlee       Female 34
# 6   Druci      Brandli      Female 39
# 7   Rutledge   Hallt        Male   23
# 8   Nancie     Vian         Female 74
# 9   Duff       Karlowicz    Male   50
# 10  Barthel    Docket       Male   72
# 11  Rockwell   Matson       Male   94
# 12  Wheeler    Winward      Male   48
# 13  Olag                    Male   60
# 14  Melba      Spellacy     Female 38
# 15  Mandie     Feares       Female 32
# 16  Marcelia   Monkleigh    Female 61
# 17  Winnifred  Beswetherick Female 83
# 18  Odilia     Quick        Female 65
# 19  Karly      Willavize    Female  2
# 20  Teddie     Burchill     Male   11
# 21  Gaston     Dallaghan    Male   44
# 22  Brena      Schnitter    Female 78
# 23  Dyane      Burwell      Female 19
# ...

# %%
# most common cusotmer job industry
chart4 <- qplot(data2$job_industry_category, geom = "bar", xlab = "Job Industry Category",
               ylab = "Occurances", 
               main = "Most common cusotmer job industry") + aes(fill = ..count..) + theme(axis.text.x = element_text(angle = 90))
chart4
# Out:
# plot without title

# %% [markdown]
# Most of the customer for Sprocket are from the financial sector, and manifacturing comes in second

# %%
#customer wealth
chart5 <- qplot(data2$wealth_segment, geom = "bar", xlab = "Customer Wealth Segment",
               ylab = "Count", main = "Customer Wealth Segment") + aes(fill = ..count..)
chart5
# Out:
# plot without title

# %% [markdown]
# Most of Sprocket's customer are from the Mass segment of customers

# %%
#Gender breakdown of Customers
chart6 <- qplot(data2$gender, geom = "bar", xlab = "Gender", ylab = "Count",
               main = "Gender Breakdown of Cusotmers") + aes(fill = ..count..)
chart6
# Out:
# plot without title

# %% [markdown]
# Female clients have made more transactions than male clients

# %% [markdown]
# ### 4. Conclusion
#
# #### Trends we see:
# 1. Customer prefered brand is Solex
# 2. Most customers are 42 years old
# 3. Females make a majority of Sprocket's customer base
# 4. WeareA2B brings in the most profit
# 5. Females contribute to the most bike related purchases in the last 3 years
# 6. Most customers are form New South Wales
# 7. Most customers are from the financial sector
#
# #### Focus on customers that:
# 1. Mass customer segment
# 2. Female customers
# 3. Customers live in NSW
# 4. Customers in the financial sector make the most transactions
#
# #### Marketing and Growth Strategy
# 1. Focus on afordibility of the Solex Brand that will be for the Mass customer segment.
# 2. Advertizing can be female focused while also trageting the NSW area of Australia
#
#     Example: Can focus on light colored banners for the NSW area
